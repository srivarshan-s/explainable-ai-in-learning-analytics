# %% [markdown]
# ### **ENVIRONMENT SETUP**

# %%
# ! rm -r data*
# ! wget http://argumentation.bplaced.net/arguana-data/dagstuhl-15512-argquality-corpus-v2.zip
# ! unzip dagstuhl-15512-argquality-corpus-v2.zip
# ! rm *.zip
# ! rm -r __MACOSX
# ! mv dagstuhl-15512-argquality-corpus-v2 data

# %% [markdown]
# ### **IMPORT LIBRARIES**

# %%
# Set random seed

import random
random.seed(14071)

# %%
import re
import pandas as pd
import numpy as np

import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer

from sklearn.feature_extraction.text import CountVectorizer # Bag of Words
from sklearn.feature_extraction.text import TfidfVectorizer # TF-IDF

from sklearn.preprocessing import LabelEncoder # Label Encoding
from sklearn.preprocessing import OneHotEncoder # One Hot Encoding

from sklearn.model_selection import train_test_split # Train Test Split
from sklearn.model_selection import cross_val_score, cross_val_predict # Cross validation

from sklearn.linear_model import LogisticRegression # LR Model
from sklearn.tree import DecisionTreeClassifier # DT Model
from sklearn.ensemble import RandomForestClassifier # RF Model

import tensorflow.keras as keras # Keras bindings
import tensorflow as tf # Tensorflow bindings

from sklearn.metrics import classification_report # Classification Report

from sklearn.model_selection import GridSearchCV # Grid Search
# Out:
# [nltk_data] Downloading package stopwords to /home/sri/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/sri/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/sri/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/sri/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ### **IMPORT DATA**

# %%
df = pd.read_csv("data/dagstuhl-15512-argquality-corpus-annotated.csv", sep='\t', encoding_errors="ignore")

# %%
df
# Out:
#      annotator argumentative overall quality local acceptability  \
# 0            1             y         1 (Low)             1 (Low)
# 1            2             y         1 (Low)            3 (High)
# 2            3             y     2 (Average)         2 (Average)
# 3            1             y     2 (Average)            3 (High)
# 4            2             y         1 (Low)         2 (Average)
# ..         ...           ...             ...                 ...
# 955          2             y     2 (Average)         2 (Average)
# 956          3             y     2 (Average)         2 (Average)
# 957          1             y     2 (Average)         2 (Average)
# 958          2             y     2 (Average)         2 (Average)
# 959          3             y     2 (Average)         2 (Average)
#
#     appropriateness  arrangement      clarity      cogency effectiveness  \
# 0           1 (Low)      1 (Low)  2 (Average)      1 (Low)       1 (Low)
# 1       2 (Average)  2 (Average)     3 (High)      1 (Low)       1 (Low)
# 2       2 (Average)  2 (Average)  2 (Average)  2 (Average)   2 (Average)
# 3       2 (Average)  2 (Average)  2 (Average)  2 (Average)   2 (Average)
# 4           1 (Low)  2 (Average)  2 (Average)      1 (Low)       1 (Low)
# ..              ...          ...          ...          ...           ...
# 955        3 (High)  2 (Average)  2 (Average)      1 (Low)       1 (Low)
# 956     2 (Average)  2 (Average)  2 (Average)  2 (Average)   2 (Average)
# 957     2 (Average)  2 (Average)      1 (Low)  2 (Average)   2 (Average)
# 958        3 (High)  2 (Average)     3 (High)      1 (Low)   2 (Average)
# 959     2 (Average)  2 (Average)  2 (Average)  2 (Average)   2 (Average)
#
#     global acceptability  ... global sufficiency reasonableness  \
# 0                1 (Low)  ...            1 (Low)        1 (Low)
# 1               3 (High)  ...            1 (Low)    2 (Average)
# 2            2 (Average)  ...        2 (Average)    2 (Average)
# 3            2 (Average)  ...        2 (Average)    2 (Average)
# 4            2 (Average)  ...            1 (Low)        1 (Low)
# ..                   ...  ...                ...            ...
# 955             3 (High)  ...            1 (Low)    2 (Average)
# 956          2 (Average)  ...        2 (Average)    2 (Average)
# 957          2 (Average)  ...        2 (Average)    2 (Average)
# 958          2 (Average)  ...            1 (Low)    2 (Average)
# 959          2 (Average)  ...        2 (Average)    2 (Average)
#
#     local relevance  credibility emotional appeal  sufficiency  \
# 0           1 (Low)      1 (Low)          1 (Low)      1 (Low)
# 1       2 (Average)  2 (Average)      2 (Average)      1 (Low)
# 2          3 (High)  2 (Average)          1 (Low)  2 (Average)
# 3          3 (High)     3 (High)      2 (Average)  2 (Average)
# 4       2 (Average)  2 (Average)      2 (Average)      1 (Low)
# ..              ...          ...              ...          ...
# 955     2 (Average)  2 (Average)      2 (Average)      1 (Low)
# 956        3 (High)  2 (Average)      2 (Average)  2 (Average)
# 957        3 (High)  2 (Average)      2 (Average)  2 (Average)
# 958     2 (Average)  2 (Average)         3 (High)      1 (Low)
# 959        3 (High)  2 (Average)      2 (Average)  2 (Average)
#
#                                               argument        #id  \
# 0    it is true that bottled water is a waste, but ...  arg219250
# 1    it is true that bottled water is a waste, but ...  arg219250
# 2    it is true that bottled water is a waste, but ...  arg219250
# 3    Most Americans on average recycle 86-88% of th...  arg219293
# 4    Most Americans on average recycle 86-88% of th...  arg219293
# ..                                                 ...        ...
# 955  Raffles neglected Singapore when he went aroun...  arg168822
# 956  Raffles neglected Singapore when he went aroun...  arg168822
# 957  Raffles doesn't care about the citizens, doesn...  arg168834
# 958  Raffles doesn't care about the citizens, doesn...  arg168834
# 959  Raffles doesn't care about the citizens, doesn...  arg168834
#
#                                                  issue                  stance
# 0                            ban-plastic-water-bottles  no-bad-for-the-economy
# 1                            ban-plastic-water-bottles  no-bad-for-the-economy
# 2                            ban-plastic-water-bottles  no-bad-for-the-economy
# 3                            ban-plastic-water-bottles  no-bad-for-the-economy
# 4                            ban-plastic-water-bottles  no-bad-for-the-economy
# ..                                                 ...                     ...
# 955  william-farquhar-ought-to-be-honoured-as-the-r...           yes-of-course
# 956  william-farquhar-ought-to-be-honoured-as-the-r...           yes-of-course
# 957  william-farquhar-ought-to-be-honoured-as-the-r...           yes-of-course
# 958  william-farquhar-ought-to-be-honoured-as-the-r...           yes-of-course
# 959  william-farquhar-ought-to-be-honoured-as-the-r...           yes-of-course
#
# [960 rows x 21 columns]

# %%
print(f"Number of annotations = {len(df['argument'])}")
print(f"Number of unique arguements = {len(np.unique(df['argument']))}") # Each argument was scored by 3 annotators
print(f"Number of unique issue = {len(np.unique(df['issue']))}")  # There are a total of 16 issues
print(f"Number of unique stance = {len(np.unique(df['stance']))}") # Each issue has on an avg 2 stance (positive and negative)
# Out:
# Number of annotations = 960
# Number of unique arguements = 320
# Number of unique issue = 16
# Number of unique stance = 28

# %% [markdown]
# ### **DATA CLEANING**

# %% [markdown]
# #### Remove statements are that are tagged as NOT argumentative

# %%
df[df["argumentative"] == "n"] # Statements that are tagged as NOT argumentative
# Out:
#      annotator argumentative overall quality local acceptability  \
# 25           2             n             NaN                 NaN
# 32           3             n             NaN                 NaN
# 37           2             n             NaN                 NaN
# 51           1             n             NaN                 NaN
# 52           2             n             NaN                 NaN
# 53           3             n             NaN                 NaN
# 97           2             n             NaN                 NaN
# 104          3             n             NaN                 NaN
# 105          1             n             NaN                 NaN
# 106          2             n             NaN                 NaN
# 107          3             n             NaN                 NaN
# 110          3             n             NaN                 NaN
# 113          3             n             NaN                 NaN
# 121          2             n             NaN                 NaN
# 126          1             n             NaN                 NaN
# 127          2             n             NaN                 NaN
# 128          3             n             NaN                 NaN
# 148          2             n             NaN                 NaN
# 162          1             n             NaN                 NaN
# 233          3             n             NaN                 NaN
# 264          1             n             NaN                 NaN
# 265          2             n             NaN                 NaN
# 266          3             n             NaN                 NaN
# 441          2             n             NaN                 NaN
# 442          1             n             NaN                 NaN
#
#     appropriateness arrangement clarity cogency effectiveness  \
# 25              NaN         NaN     NaN     NaN           NaN
# 32              NaN         NaN     NaN     NaN           NaN
# 37              NaN         NaN     NaN     NaN           NaN
# 51              NaN         NaN     NaN     NaN           NaN
# 52              NaN         NaN     NaN     NaN           NaN
# 53              NaN         NaN     NaN     NaN           NaN
# 97              NaN         NaN     NaN     NaN           NaN
# 104             NaN         NaN     NaN     NaN           NaN
# 105             NaN         NaN     NaN     NaN           NaN
# 106             NaN         NaN     NaN     NaN           NaN
# 107             NaN         NaN     NaN     NaN           NaN
# 110             NaN         NaN     NaN     NaN           NaN
# 113             NaN         NaN     NaN     NaN           NaN
# 121             NaN         NaN     NaN     NaN           NaN
# 126             NaN         NaN     NaN     NaN           NaN
# 127             NaN         NaN     NaN     NaN           NaN
# 128             NaN         NaN     NaN     NaN           NaN
# 148             NaN         NaN     NaN     NaN           NaN
# 162             NaN         NaN     NaN     NaN           NaN
# 233             NaN         NaN     NaN     NaN           NaN
# 264             NaN         NaN     NaN     NaN           NaN
# 265             NaN         NaN     NaN     NaN           NaN
# 266             NaN         NaN     NaN     NaN           NaN
# 441             NaN         NaN     NaN     NaN           NaN
# 442             NaN         NaN     NaN     NaN           NaN
#
#     global acceptability  ... global sufficiency reasonableness  \
# 25                   NaN  ...                NaN            NaN
# 32                   NaN  ...                NaN            NaN
# 37                   NaN  ...                NaN            NaN
# 51                   NaN  ...                NaN            NaN
# 52                   NaN  ...                NaN            NaN
# 53                   NaN  ...                NaN            NaN
# 97                   NaN  ...                NaN            NaN
# 104                  NaN  ...                NaN            NaN
# 105                  NaN  ...                NaN            NaN
# 106                  NaN  ...                NaN            NaN
# 107                  NaN  ...                NaN            NaN
# 110                  NaN  ...                NaN            NaN
# 113                  NaN  ...                NaN            NaN
# 121                  NaN  ...                NaN            NaN
# 126                  NaN  ...                NaN            NaN
# 127                  NaN  ...                NaN            NaN
# 128                  NaN  ...                NaN            NaN
# 148                  NaN  ...                NaN            NaN
# 162                  NaN  ...                NaN            NaN
# 233                  NaN  ...                NaN            NaN
# 264                  NaN  ...                NaN            NaN
# 265                  NaN  ...                NaN            NaN
# 266                  NaN  ...                NaN            NaN
# 441                  NaN  ...                NaN            NaN
# 442                  NaN  ...                NaN            NaN
#
#     local relevance credibility emotional appeal sufficiency  \
# 25              NaN         NaN              NaN         NaN
# 32              NaN         NaN              NaN         NaN
# 37              NaN         NaN              NaN         NaN
# 51              NaN         NaN              NaN         NaN
# 52              NaN         NaN              NaN         NaN
# 53              NaN         NaN              NaN         NaN
# 97              NaN         NaN              NaN         NaN
# 104             NaN         NaN              NaN         NaN
# 105             NaN         NaN              NaN         NaN
# 106             NaN         NaN              NaN         NaN
# 107             NaN         NaN              NaN         NaN
# 110             NaN         NaN              NaN         NaN
# 113             NaN         NaN              NaN         NaN
# 121             NaN         NaN              NaN         NaN
# 126             NaN         NaN              NaN         NaN
# 127             NaN         NaN              NaN         NaN
# 128             NaN         NaN              NaN         NaN
# 148             NaN         NaN              NaN         NaN
# 162             NaN         NaN              NaN         NaN
# 233             NaN         NaN              NaN         NaN
# 264             NaN         NaN              NaN         NaN
# 265             NaN         NaN              NaN         NaN
# 266             NaN         NaN              NaN         NaN
# 441             NaN         NaN              NaN         NaN
# 442             NaN         NaN              NaN         NaN
#
#                                               argument        #id  \
# 25   We will be able to ban water bottles until we ...  arg219242
# 32   The high price of bottled water is not the wat...  arg219232
# 37   A drop of water is worth more than a sack of g...  arg219210
# 51   Yeah I have a bottle of water next to me its n...  arg219292
# 52   Yeah I have a bottle of water next to me its n...  arg219292
# 53   Yeah I have a bottle of water next to me its n...  arg219292
# 97   This is just wrong we should not insult who we...  arg236317
# 104  I have a personal relationship with Christ. I ...  arg317490
# 105  God helps those who help themselves! So i will...  arg234318
# 106  God helps those who help themselves! So i will...  arg234318
# 107  God helps those who help themselves! So i will...  arg234318
# 110  I was raised in a Freewill Baptist Church and ...  arg236641
# 113  I found more peace in my belief and will conti...  arg230311
# 121  If evealution is real find me someone/somethin...      70818
# 126  Could a unproven higher power have created a p...      68938
# 127  Could a unproven higher power have created a p...      68938
# 128  Could a unproven higher power have created a p...      68938
# 148  Our world could be a giant hologram <br/> http...      44125
# 162  Unfortunately, most of what sabrejimmy says is...        804
# 233  Most of the government sites in India is desig...      71467
# 264  The "who gives a crap" button was your browser...        541
# 265  The "who gives a crap" button was your browser...        541
# 266  The "who gives a crap" button was your browser...        541
# 441  stupid india they actually really suck. so, BO...  arg155750
# 442  stupid india they actually really suck. so, BO...  arg155750
#
#                                          issue  \
# 25                   ban-plastic-water-bottles
# 32                   ban-plastic-water-bottles
# 37                   ban-plastic-water-bottles
# 51                   ban-plastic-water-bottles
# 52                   ban-plastic-water-bottles
# 53                   ban-plastic-water-bottles
# 97                     christianity-or-atheism
# 104                    christianity-or-atheism
# 105                    christianity-or-atheism
# 106                    christianity-or-atheism
# 107                    christianity-or-atheism
# 110                    christianity-or-atheism
# 113                    christianity-or-atheism
# 121                      evolution-vs-creation
# 126                      evolution-vs-creation
# 127                      evolution-vs-creation
# 128                      evolution-vs-creation
# 148                      evolution-vs-creation
# 162                      evolution-vs-creation
# 233               firefox-vs-internet-explorer
# 264                gay-marriage-right-or-wrong
# 265                gay-marriage-right-or-wrong
# 266                gay-marriage-right-or-wrong
# 441  india-has-the-potential-to-lead-the-world
# 442  india-has-the-potential-to-lead-the-world
#
#                                                 stance
# 25                              no-bad-for-the-economy
# 32                                yes-emergencies-only
# 37                                yes-emergencies-only
# 51                                yes-emergencies-only
# 52                                yes-emergencies-only
# 53                                yes-emergencies-only
# 97                                        christianity
# 104                                       christianity
# 105                                       christianity
# 106                                       christianity
# 107                                       christianity
# 110                                       christianity
# 113                                       christianity
# 121                                           creation
# 126                                           creation
# 127                                           creation
# 128                                           creation
# 148                                           creation
# 162                                          evolution
# 233  there-s-more-browsers-than-the-ie-firefox-is-a...
# 264                     allowing-gay-marriage-is-right
# 265                     allowing-gay-marriage-is-right
# 266                     allowing-gay-marriage-is-right
# 441                                         no-against
# 442                                         no-against
#
# [25 rows x 21 columns]

# %%
statements = df[df["argumentative"] == "n"]["argument"].to_numpy() # Extract the statements
statements = np.unique(statements) # Extract the unique statements

for ele in statements: # Remove all occurrences of NOT argumentative statements
    df.drop(df[df['argument'] == ele].index, axis=0, inplace=True)

# %%
df[df["argumentative"] == "n"]
# Out:
# Empty DataFrame
# Columns: [annotator, argumentative, overall quality, local acceptability, appropriateness, arrangement, clarity, cogency, effectiveness, global acceptability, global relevance, global sufficiency, reasonableness, local relevance, credibility, emotional appeal, sufficiency, argument, #id, issue, stance]
# Index: []
#
# [0 rows x 21 columns]

# %%
print(f"Number of annotations = {len(df['argument'])}")
print(f"Number of unique arguements = {len(np.unique(df['argument']))}") # Each argument was scored by 3 annotators
print(f"Number of unique issue = {len(np.unique(df['issue']))}")  # There are a total of 16 issues
print(f"Number of unique stance = {len(np.unique(df['stance']))}") # Each issue has on an avg 2 stance (positive and negative)
# Out:
# Number of annotations = 912
# Number of unique arguements = 304
# Number of unique issue = 16
# Number of unique stance = 28

# %% [markdown]
# #### Combine all Annotators' scores into a single score

# %%
argument = np.unique(df["argument"])

# %%
attributes = ["annotator", "overall quality", "cogency", "effectiveness", "reasonableness", "argument", "#id"]

cleaned_df = []

for arg in argument:

    new_df = df[df["argument"] == arg][attributes]
    flag = 0
    new_dict = {
        "#id": new_df["#id"].iloc[0],
        "argument": new_df["argument"].iloc[0],
    }

    for ele in ["overall quality", "cogency", "effectiveness", "reasonableness"]:
        if len(pd.value_counts(new_df[ele])) == 3:
            flag = 1
            break
        new_dict[ele] = pd.value_counts(new_df[ele]).index[0]
        
    if flag == 1:
        continue
    cleaned_df.append(new_dict)

cleaned_df = pd.DataFrame(cleaned_df)

# %%
df[df["#id"] == "28068"]
# Out:
#      annotator argumentative overall quality local acceptability  \
# 144          1             y     2 (Average)         2 (Average)
# 145          2             y         1 (Low)             1 (Low)
# 146          3             y     2 (Average)         2 (Average)
#
#     appropriateness  arrangement      clarity      cogency effectiveness  \
# 144     2 (Average)  2 (Average)  2 (Average)      1 (Low)       1 (Low)
# 145        3 (High)  2 (Average)  2 (Average)      1 (Low)       1 (Low)
# 146     2 (Average)  2 (Average)     3 (High)  2 (Average)       1 (Low)
#
#     global acceptability  ... global sufficiency reasonableness  \
# 144              1 (Low)  ...            1 (Low)        1 (Low)
# 145              1 (Low)  ...            1 (Low)        1 (Low)
# 146          2 (Average)  ...            1 (Low)        1 (Low)
#
#     local relevance credibility emotional appeal  sufficiency  \
# 144        3 (High)     1 (Low)      2 (Average)      1 (Low)
# 145     2 (Average)     1 (Low)      2 (Average)      1 (Low)
# 146     2 (Average)     1 (Low)      2 (Average)  2 (Average)
#
#                                               argument    #id  \
# 144  "Debates are based on convincing evidence. The...  28068
# 145  "Debates are based on convincing evidence. The...  28068
# 146  "Debates are based on convincing evidence. The...  28068
#
#                      issue    stance
# 144  evolution-vs-creation  creation
# 145  evolution-vs-creation  creation
# 146  evolution-vs-creation  creation
#
# [3 rows x 21 columns]

# %%
cleaned_df
# Out:
#            #id                                           argument  \
# 0        28068  "Debates are based on convincing evidence. The...
# 1        13270  "If a women is raped" is a good argument. Howe...
# 2        13275  "The government has no place to tell a woman w...
# 3        12365  (I am writing this through Firefox) Emotions a...
# 4    arg561672  1. It makes everyone equal - if children can w...
# ..         ...                                                ...
# 256  arg334959  yea, because even though there are many other ...
# 257  arg335089  yes because if they fear getting hit than they...
# 258  arg203922  yes, i believe it's nice to have a school unif...
# 259  arg596217  yes,India has potential to lead the world.So, ...
# 260  arg399268  you can get the "Foxtel Go" app on your Ipad s...
#
#     overall quality      cogency effectiveness reasonableness
# 0       2 (Average)      1 (Low)       1 (Low)        1 (Low)
# 1           1 (Low)      1 (Low)       1 (Low)        1 (Low)
# 2           1 (Low)      1 (Low)       1 (Low)        1 (Low)
# 3       2 (Average)      1 (Low)       1 (Low)    2 (Average)
# 4           1 (Low)  2 (Average)       1 (Low)    2 (Average)
# ..              ...          ...           ...            ...
# 256     2 (Average)  2 (Average)       1 (Low)    2 (Average)
# 257         1 (Low)      1 (Low)       1 (Low)        1 (Low)
# 258     2 (Average)  2 (Average)       1 (Low)    2 (Average)
# 259         1 (Low)      1 (Low)       1 (Low)        1 (Low)
# 260         1 (Low)      1 (Low)       1 (Low)        1 (Low)
#
# [261 rows x 6 columns]

# %%
print(f"Number of arguements = {len(cleaned_df['argument'])}")
# Out:
# Number of arguements = 261

# %% [markdown]
# ### **DATA PREPROCESSING**

# %%
text = cleaned_df["argument"]

# %%
stop_words = set(stopwords.words("english"))
english_stopwords = stopwords.words("english")
english_stemmer = SnowballStemmer("english")

# %%
def clean_text(text):
    text = text.replace('</br>', '') # Remove </br>
    text = re.sub(r'[^\w]', ' ', text) # Remove symbols
    text = re.sub(r'[ ]{2,}', ' ', text) # Remove extra spaces
    text = re.sub(r'[ \t]+$', '', text) # Remove trailing white spaces
    tokens = []
    for token in text.split():
        if token not in stop_words:
            token = english_stemmer.stem(token)
            tokens.append(token)
    return " ".join(tokens)
    #return token

# %%
cleaned_text = [clean_text(text) for text in text]
text = cleaned_text

# %% [markdown]
# ### **VECTORIZE THE TEXT DATA**

# %%
# Using Bag of Words (BoW)

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(text)
X = X.toarray()

print(f"Shape of Vector = {X.shape}")
# Out:
# Shape of Vector = (261, 2001)

# %% [markdown]
# ### **PREDICTING OVERALL QUALITY FROM TEXT**

# %%
y = cleaned_df["overall quality"].to_numpy()
y = y.reshape(-1, 1)

# %% [markdown]
# #### Label Encoding

# %%
# Label Encoding

encoder = LabelEncoder()
enc_y = encoder.fit_transform(y)

print(f"Size of Labels = {enc_y.shape}")
# Out:
# Size of Labels = (261,)
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# #### Train Test Split

# %%
X_train, X_test, y_train, y_test= train_test_split(X, enc_y, test_size=0.2, random_state=110)

print(f"Shape of Training Data: {X_train.shape}")
print(f"Shape of Training Labels: {y_train.shape}")
print(f"Shape of Testing Data: {X_test.shape}")
print(f"Shape of Testing Labels: {y_test.shape}")
# Out:
# Shape of Training Data: (208, 2001)
# Shape of Training Labels: (208,)
# Shape of Testing Data: (53, 2001)
# Shape of Testing Labels: (53,)

# %% [markdown]
# #### Training Logistic Regression Model

# %%
model = LogisticRegression(C=0.1, dual=False, fit_intercept=True, penalty="l2", solver="newton-cg") # BoW
# model = LogisticRegression(C=0.01, dual=True, fit_intercept=False, penalty="l2", solver="liblinear") # TF-IDF
model.fit(X=X_train, y=y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

print(f"Training Accuracy = {classification_report(y_train, pred_train, output_dict=True)['accuracy']}")
print(f"Testing Accuracy = {classification_report(y_test, pred_test, output_dict=True)['accuracy']}")
# Out:
# Training Accuracy = 0.9759615384615384
# Testing Accuracy = 0.5660377358490566
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.96      0.69        26
#            1       0.71      0.20      0.31        25
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.57        53
#    macro avg       0.42      0.39      0.34        53
# weighted avg       0.60      0.57      0.49        53
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Cross Validation

model = LogisticRegression(C=0.1, dual=False, fit_intercept=True, penalty="l2", solver="newton-cg")
# scores = cross_val_score(model, X, enc_y, cv=5)
pred = cross_val_predict(model, X, enc_y, cv=5)
print(classification_report(enc_y, pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.86      0.73       149
#            1       0.54      0.33      0.41        96
#            2       0.00      0.00      0.00        16
#
#     accuracy                           0.61       261
#    macro avg       0.39      0.40      0.38       261
# weighted avg       0.56      0.61      0.57       261

# %%
# # Grid Search

# parameters = {
#     "penalty": ["l1", "l2", "elasticnet", "none"],
#     "dual": [True, False],
#     "C": [1, 0.1, 0.01],
#     "fit_intercept": [True, False],
#     "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],
# }

# model = LogisticRegression()

# grid_search = GridSearchCV(model, parameters, n_jobs=-1)
# grid_search.fit(X_train, y_train)

# grid_search.best_params_

# %% [markdown]
# #### Training Decision Tree Model

# %%
model = DecisionTreeClassifier(criterion="gini", max_features="sqrt", splitter="random") # BoW
# model = DecisionTreeClassifier(criterion="entropy", max_features="auto", splitter="random") # TF-IDF
model.fit(X=X_train, y=y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

print(f"Training Accuracy = {classification_report(y_train, pred_train, output_dict=True)['accuracy']}")
print(f"Testing Accuracy = {classification_report(y_test, pred_test, output_dict=True)['accuracy']}")
# Out:
# Training Accuracy = 1.0
# Testing Accuracy = 0.6226415094339622
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.85      0.69        26
#            1       0.73      0.44      0.55        25
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.62        53
#    macro avg       0.44      0.43      0.41        53
# weighted avg       0.63      0.62      0.60        53
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# # Grid Search

# parameters = {
#     "criterion": ["gini", "entropy", "log_loss"],
#     "splitter": ["best", "random"],
#     "max_features": ["auto", "sqrt", "log2", None],
# }

# model = DecisionTreeClassifier()

# grid_search = GridSearchCV(model, parameters, n_jobs=-1)
# grid_search.fit(X_train, y_train)

# grid_search.best_params_

# %% [markdown]
# #### Training Random Forest Model

# %%
model = RandomForestClassifier() # BoW
# model = RandomForestClassifier(bootstrap=False, class_weight=None, 
#     criterion="entropy", max_features="sqrt", n_estimators=100, oob_score=False, warm_start=False) # TF-IDF
model.fit(X=X_train, y=y_train)

pred_train = model.predict(X_train)
pred_test = model.predict(X_test)

print(f"Training Accuracy = {classification_report(y_train, pred_train, output_dict=True)['accuracy']}")
print(f"Testing Accuracy = {classification_report(y_test, pred_test, output_dict=True)['accuracy']}")
# Out:
# Training Accuracy = 1.0
# Testing Accuracy = 0.5094339622641509
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.51      0.92      0.66        26
#            1       0.50      0.12      0.19        25
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.51        53
#    macro avg       0.34      0.35      0.28        53
# weighted avg       0.49      0.51      0.41        53
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# # Grid Search

# parameters = {
#     "n_estimators": [100, 200, 300],
#     "criterion": ["gini", "entropy", "log_loss"],
#     "max_features": ["auto", "sqrt", "log2", None],
#     "bootstrap": [True, False],
#     "oob_score": [True, False],
#     "warm_start": [True, False],
#     "class_weight": ["balanced", "balanced_subsample", None],
# }

# model = RandomForestClassifier()

# grid_search = GridSearchCV(model, parameters, n_jobs=-1)
# grid_search.fit(X_train, y_train)

# grid_search.best_params_

# %% [markdown]
# #### Training Neural Network

# %%
# One Hot Encoding

encoder = OneHotEncoder()
enc_y = encoder.fit_transform(y)
enc_y = enc_y.toarray()

print(f"Size of Labels = {enc_y.shape}")
print(f"Label Sample: {enc_y[0]}")
# Out:
# Size of Labels = (261, 3)
# Label Sample: [0. 1. 0.]

# %%
# Train Test Split

X_train, X_test, y_train, y_test= train_test_split(X, enc_y, test_size=0.2, random_state=110)

print(f"Shape of Training Data: {X_train.shape}")
print(f"Shape of Training Labels: {y_train.shape}")
print(f"Shape of Testing Data: {X_test.shape}")
print(f"Shape of Testing Labels: {y_test.shape}")
# Out:
# Shape of Training Data: (208, 2001)
# Shape of Training Labels: (208, 3)
# Shape of Testing Data: (53, 2001)
# Shape of Testing Labels: (53, 3)

# %%
# Define Custom Callback

class MyThresholdCallback(tf.keras.callbacks.Callback):
    def __init__(self, threshold):
        super(MyThresholdCallback, self).__init__()
        self.threshold = threshold
 
    def on_epoch_end(self, epoch, logs=None): 
        val_acc = logs["val_accuracy"]
        if val_acc >= self.threshold:
            self.model.stop_training = True

# %%
# Define Model
model = keras.models.Sequential([
    keras.layers.Dense(32, input_dim=X_train.shape[1], activation="relu"),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(128, activation="relu"),
    keras.layers.Dropout(0.6),
    keras.layers.Dense(64, activation="relu"),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(3, activation="softmax"),
])

loss_function = keras.losses.CategoricalCrossentropy() # Define loss function
# loss_function = keras.losses.SparseCategoricalCrossentropy() # Define loss function
optimizer = keras.optimizers.SGD(learning_rate=0.005) # Define optimizer

callback = MyThresholdCallback(threshold=0.67) # Set callback at 67% accuracy

model.compile(optimizer=optimizer, loss=loss_function, metrics=["accuracy"]) # Compile the model

# %%
# Train the model

history = model.fit(X_train, y_train, epochs=100, batch_size=1, 
    validation_data=(X_test, y_test), callbacks=[callback])
# Out:
# Epoch 1/100
# 208/208 [==============================] - 1s 4ms/step - loss: 1.0472 - accuracy: 0.4663 - val_loss: 0.9687 - val_accuracy: 0.4906
# Epoch 2/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.9248 - accuracy: 0.6010 - val_loss: 0.9283 - val_accuracy: 0.4906
# Epoch 3/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.8711 - accuracy: 0.6058 - val_loss: 0.9115 - val_accuracy: 0.4906
# Epoch 4/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.8158 - accuracy: 0.6587 - val_loss: 0.9100 - val_accuracy: 0.4906
# Epoch 5/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.8245 - accuracy: 0.6635 - val_loss: 0.8745 - val_accuracy: 0.4906
# Epoch 6/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.7565 - accuracy: 0.6923 - val_loss: 0.8858 - val_accuracy: 0.4906
# Epoch 7/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.7149 - accuracy: 0.7596 - val_loss: 0.8861 - val_accuracy: 0.4717
# Epoch 8/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.6683 - accuracy: 0.7548 - val_loss: 0.9043 - val_accuracy: 0.4717
# Epoch 9/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.6166 - accuracy: 0.7740 - val_loss: 0.8924 - val_accuracy: 0.5094
# Epoch 10/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.5530 - accuracy: 0.8125 - val_loss: 0.9586 - val_accuracy: 0.5094
# Epoch 11/100
# 208/208 [==============================] - 1s 4ms/step - loss: 0.5114 - accuracy: 0.8365 - val_loss: 0.9014 - val_accuracy: 0.5660
# Epoch 12/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.4752 - accuracy: 0.8558 - val_loss: 0.9369 - val_accuracy: 0.5849
# Epoch 13/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.4279 - accuracy: 0.8750 - val_loss: 0.9226 - val_accuracy: 0.5472
# Epoch 14/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.4472 - accuracy: 0.8654 - val_loss: 0.9927 - val_accuracy: 0.5660
# Epoch 15/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3515 - accuracy: 0.8798 - val_loss: 0.9123 - val_accuracy: 0.5660
# Epoch 16/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3254 - accuracy: 0.8990 - val_loss: 0.9348 - val_accuracy: 0.5660
# Epoch 17/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3687 - accuracy: 0.8846 - val_loss: 0.9916 - val_accuracy: 0.5849
# Epoch 18/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3155 - accuracy: 0.8942 - val_loss: 0.9377 - val_accuracy: 0.5849
# Epoch 19/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3114 - accuracy: 0.8990 - val_loss: 0.9925 - val_accuracy: 0.5660
# Epoch 20/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2827 - accuracy: 0.8942 - val_loss: 1.0152 - val_accuracy: 0.5660
# Epoch 21/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3139 - accuracy: 0.8990 - val_loss: 1.0443 - val_accuracy: 0.5472
# Epoch 22/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2815 - accuracy: 0.9183 - val_loss: 0.9983 - val_accuracy: 0.5849
# Epoch 23/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.3413 - accuracy: 0.8846 - val_loss: 0.9781 - val_accuracy: 0.6038
# Epoch 24/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2109 - accuracy: 0.9375 - val_loss: 1.0368 - val_accuracy: 0.5849
# Epoch 25/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2428 - accuracy: 0.9231 - val_loss: 1.0172 - val_accuracy: 0.6038
# Epoch 26/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2055 - accuracy: 0.9231 - val_loss: 1.0422 - val_accuracy: 0.6038
# Epoch 27/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2388 - accuracy: 0.9231 - val_loss: 1.0058 - val_accuracy: 0.6226
# Epoch 28/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2075 - accuracy: 0.9183 - val_loss: 0.9656 - val_accuracy: 0.6415
# Epoch 29/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2491 - accuracy: 0.9231 - val_loss: 0.9889 - val_accuracy: 0.6038
# Epoch 30/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1650 - accuracy: 0.9519 - val_loss: 1.0628 - val_accuracy: 0.6226
# Epoch 31/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1756 - accuracy: 0.9567 - val_loss: 1.0704 - val_accuracy: 0.6038
# Epoch 32/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2053 - accuracy: 0.9279 - val_loss: 1.0378 - val_accuracy: 0.6038
# Epoch 33/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1680 - accuracy: 0.9471 - val_loss: 1.0812 - val_accuracy: 0.6226
# Epoch 34/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.1711 - accuracy: 0.9471 - val_loss: 1.1163 - val_accuracy: 0.6415
# Epoch 35/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.1983 - accuracy: 0.9375 - val_loss: 1.0708 - val_accuracy: 0.5660
# Epoch 36/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1546 - accuracy: 0.9615 - val_loss: 1.1072 - val_accuracy: 0.5849
# Epoch 37/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1689 - accuracy: 0.9519 - val_loss: 1.1599 - val_accuracy: 0.6226
# Epoch 38/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1923 - accuracy: 0.9375 - val_loss: 1.1194 - val_accuracy: 0.6038
# Epoch 39/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1671 - accuracy: 0.9567 - val_loss: 1.1447 - val_accuracy: 0.5849
# Epoch 40/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.2369 - accuracy: 0.9375 - val_loss: 1.1287 - val_accuracy: 0.6415
# Epoch 41/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1180 - accuracy: 0.9712 - val_loss: 1.2424 - val_accuracy: 0.5660
# Epoch 42/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1146 - accuracy: 0.9615 - val_loss: 1.1602 - val_accuracy: 0.6038
# Epoch 43/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.1531 - accuracy: 0.9519 - val_loss: 1.1854 - val_accuracy: 0.6038
# Epoch 44/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1539 - accuracy: 0.9519 - val_loss: 1.2238 - val_accuracy: 0.6226
# Epoch 45/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1927 - accuracy: 0.9663 - val_loss: 1.2105 - val_accuracy: 0.6226
# Epoch 46/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.1094 - accuracy: 0.9760 - val_loss: 1.1760 - val_accuracy: 0.6226
# Epoch 47/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1192 - accuracy: 0.9712 - val_loss: 1.1677 - val_accuracy: 0.6415
# Epoch 48/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.1453 - accuracy: 0.9615 - val_loss: 1.2082 - val_accuracy: 0.6415
# Epoch 49/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1712 - accuracy: 0.9663 - val_loss: 1.1474 - val_accuracy: 0.6415
# Epoch 50/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1737 - accuracy: 0.9567 - val_loss: 1.1326 - val_accuracy: 0.6038
# Epoch 51/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0945 - accuracy: 0.9808 - val_loss: 1.1828 - val_accuracy: 0.6226
# Epoch 52/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1459 - accuracy: 0.9663 - val_loss: 1.1550 - val_accuracy: 0.6604
# Epoch 53/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1322 - accuracy: 0.9567 - val_loss: 1.1892 - val_accuracy: 0.6415
# Epoch 54/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1568 - accuracy: 0.9567 - val_loss: 1.1609 - val_accuracy: 0.6226
# Epoch 55/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.0726 - accuracy: 0.9856 - val_loss: 1.1999 - val_accuracy: 0.6226
# Epoch 56/100
# 208/208 [==============================] - 1s 2ms/step - loss: 0.0725 - accuracy: 0.9808 - val_loss: 1.2332 - val_accuracy: 0.6415
# Epoch 57/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0939 - accuracy: 0.9808 - val_loss: 1.2248 - val_accuracy: 0.6604
# Epoch 58/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1111 - accuracy: 0.9760 - val_loss: 1.2154 - val_accuracy: 0.6604
# Epoch 59/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.2597 - accuracy: 0.9279 - val_loss: 1.2335 - val_accuracy: 0.6415
# Epoch 60/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1274 - accuracy: 0.9615 - val_loss: 1.3430 - val_accuracy: 0.6038
# Epoch 61/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1191 - accuracy: 0.9663 - val_loss: 1.3601 - val_accuracy: 0.6226
# Epoch 62/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0957 - accuracy: 0.9808 - val_loss: 1.3603 - val_accuracy: 0.6038
# Epoch 63/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1344 - accuracy: 0.9567 - val_loss: 1.3409 - val_accuracy: 0.6226
# Epoch 64/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0687 - accuracy: 0.9808 - val_loss: 1.3252 - val_accuracy: 0.5849
# Epoch 65/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1206 - accuracy: 0.9808 - val_loss: 1.2826 - val_accuracy: 0.6038
# Epoch 66/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0808 - accuracy: 0.9856 - val_loss: 1.3174 - val_accuracy: 0.5849
# Epoch 67/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1505 - accuracy: 0.9567 - val_loss: 1.3102 - val_accuracy: 0.5849
# Epoch 68/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0856 - accuracy: 0.9808 - val_loss: 1.3167 - val_accuracy: 0.5849
# Epoch 69/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0630 - accuracy: 0.9904 - val_loss: 1.3127 - val_accuracy: 0.6038
# Epoch 70/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0717 - accuracy: 0.9856 - val_loss: 1.3043 - val_accuracy: 0.6226
# Epoch 71/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0949 - accuracy: 0.9760 - val_loss: 1.3148 - val_accuracy: 0.6226
# Epoch 72/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0826 - accuracy: 0.9712 - val_loss: 1.3446 - val_accuracy: 0.6415
# Epoch 73/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1826 - accuracy: 0.9423 - val_loss: 1.3206 - val_accuracy: 0.6038
# Epoch 74/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0645 - accuracy: 0.9808 - val_loss: 1.3129 - val_accuracy: 0.6415
# Epoch 75/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0636 - accuracy: 0.9904 - val_loss: 1.3357 - val_accuracy: 0.6415
# Epoch 76/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.0985 - accuracy: 0.9760 - val_loss: 1.3532 - val_accuracy: 0.6226
# Epoch 77/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1091 - accuracy: 0.9712 - val_loss: 1.3277 - val_accuracy: 0.6226
# Epoch 78/100
# 208/208 [==============================] - 1s 3ms/step - loss: 0.1107 - accuracy: 0.9712 - val_loss: 1.3788 - val_accuracy: 0.6792

# %%
pred_train = [np.argmax(ele) for ele in model.predict(X_train)]
pred_test = [np.argmax(ele) for ele in model.predict(X_test)]

new_y_train = [np.argmax(ele) for ele in y_train]
new_y_test = [np.argmax(ele) for ele in y_test]

print(f"Training Accuracy = {classification_report(new_y_train, pred_train, output_dict=True)['accuracy']}")
print(f"Testing Accuracy = {classification_report(new_y_test, pred_test, output_dict=True)['accuracy']}")
# Out:
# 7/7 [==============================] - 0s 2ms/step
# 2/2 [==============================] - 0s 3ms/step
# Training Accuracy = 1.0
# Testing Accuracy = 0.6792452830188679
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print(classification_report(new_y_test, pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.73      0.70        26
#            1       0.68      0.68      0.68        25
#            2       0.00      0.00      0.00         2
#
#     accuracy                           0.68        53
#    macro avg       0.45      0.47      0.46        53
# weighted avg       0.65      0.68      0.67        53
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/sri/Documents/UTS Research/explainable-ai-in-learning-analytics/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
